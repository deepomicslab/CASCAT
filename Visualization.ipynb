# %%
import matplotlib.pyplot as plt
import scanpy as sc
import warnings

warnings.simplefilter(action='ignore')

rc = {"axes.spines.left": False,
      "axes.spines.right": False,
      "axes.spines.bottom": False,
      "axes.spines.top": False,
      "xtick.bottom": False,
      "xtick.labelbottom": False,
      "ytick.labelleft": False,
      "ytick.left": False,
      "xtick.minor.visible": False,
      "xtick.top": False,
      "ytick.right": False,
      'axes.titlesize': 14,
      'legend.title_fontsize': 12,
      'legend.fontsize': 12,
      'axes.labelsize': 12,
      'lines.markersize': 3,
      'legend.markerscale': 2
      }
plt.rcParams.update(rc)

# %% [markdown]
# ## CASCAT Inputs

# %%
adata = sc.read_h5ad('./data/tree1/data.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 1000 × 1051
#     uns: 'end_id', 'milestone_network', 'milestone_percentages', 'start_id', 'timecourse'

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [cell1, cell2, cell3, cell4, cell5, cell6, cell7, cell8, cell9, cell10, cell11, cell12, cell13, cell14, cell15, cell16, cell17, cell18, cell19, cell20, cell21, cell22, cell23, cell24, cell25, cell26, cell27, cell28, cell29, cell30, cell31, cell32, cell33, cell34, cell35, cell36, cell37, cell38, cell39, cell40, cell41, cell42, cell43, cell44, cell45, cell46, cell47, cell48, cell49, cell50, cell51, cell52, cell53, cell54, cell55, cell56, cell57, cell58, cell59, cell60, cell61, cell62, cell63, cell64, cell65, cell66, cell67, cell68, cell69, cell70, cell71, cell72, cell73, cell74, cell75, cell76, cell77, cell78, cell79, cell80, cell81, cell82, cell83, cell84, cell85, cell86, cell87, cell88, cell89, cell90, cell91, cell92, cell93, cell94, cell95, cell96, cell97, cell98, cell99, cell100, ...]
#
# [1000 rows x 0 columns]

# %% [markdown]
# ## CASCAT Outputs

# %%
adata = sc.read_h5ad('result/tree1/data_processed.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 1000 × 1051
#     obs: 'cluster', 'cascat_clusters', 'cascat_pseudotime'
#     uns: 'CMI', 'cascat_connectivities', 'end_id', 'group_frac', 'log1p', 'milestone_network', 'milestone_percentages', 'root', 'start_id', 'timecourse'
#     obsm: 'cascat_embedding'
#     obsp: 'knn_adj'

# %%
from utils.Plot import plot_gt_milestone_network
plot_gt_milestone_network(adata)

# %%
from models.model_utils import *

pesudo_key = 'cascat_pseudotime'
obj = CMIPlot(adata, start_cell_idx=adata.uns['start_id'],
              root=adata.uns['root'], group_frac=adata.uns['group_frac'],
              pesudo_key='cascat_pseudotime', connect_key='cascat_connectivities',
              adj_key='knn_adj', predict_key='cascat_clusters', emb_key='cascat_embedding')
obj.plot_trajectory_tree()

# %%
obj.plot_pseudotime()
